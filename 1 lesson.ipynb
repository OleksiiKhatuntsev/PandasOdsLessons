# %%
import pandas as pd

# %%
data = pd.read_csv("adult.data.csv")

# %%
data.head(50)
# Out:
#     age         workclass  fnlwgt     education  education-num  \
# 0    39         State-gov   77516     Bachelors             13
# 1    50  Self-emp-not-inc   83311     Bachelors             13
# 2    38           Private  215646       HS-grad              9
# 3    53           Private  234721          11th              7
# 4    28           Private  338409     Bachelors             13
# 5    37           Private  284582       Masters             14
# 6    49           Private  160187           9th              5
# 7    52  Self-emp-not-inc  209642       HS-grad              9
# 8    31           Private   45781       Masters             14
# 9    42           Private  159449     Bachelors             13
# 10   37           Private  280464  Some-college             10
# 11   30         State-gov  141297     Bachelors             13
# 12   23           Private  122272     Bachelors             13
# 13   32           Private  205019    Assoc-acdm             12
# ...

# %% [markdown]
# 1. Сколько мужчин и женщин (признак sex) представлено в этом наборе данных?

# %%
data[data["sex"] == "Male"]["age"].count()
# Out:
# 21790

# %%
data[data["sex"] == "Female"]["age"].count()
# Out:
# 10771

# %% [markdown]
# 2. Каков средний возраст (признак age) женщин?

# %%
data[data["sex"] == "Female"]["age"].mean()
# Out:
# 36.85823043357163

# %% [markdown]
# 3. Какова доля граждан Германии (признак native-country)?

# %%
(data[data["native-country"] == "Germany"]["age"].count()/data["age"].count())*100
# Out:
# 0.42074874850281013

# %% [markdown]
# 4. Средние значения возраста тех, кто получает более 50К

# %%
data[data["salary"] == ">50K"]["age"].mean()
# Out:
# 44.24984058155847

# %% [markdown]
# 5. Средние значения возраста тех, кто получает менее 50К

# %%
data[data["salary"] == "<=50K"]["age"].mean()
# Out:
# 36.78373786407767

# %% [markdown]
# 6. Среднеквадратическое отклонение возраста тех, кто получает более 50К

# %%
data[data["salary"] == ">50K"]["age"].std()
# Out:
# 10.519027719851826

# %% [markdown]
# 7. Среднеквадратическое отклонение возраста тех, кто получает менее 50К

# %%
data[data["salary"] == "<=50K"]["age"].std()
# Out:
# 14.02008849082488

# %% [markdown]
# 8. Правда ли, что люди, которые получают больше 50k, имеют как минимум высшее образование? (признак education – Bachelors, Prof-school, Assoc-acdm, Assoc-voc, Masters или Doctorate)

# %%
(data[data["salary"] == ">50K"]["age"].count() - data[data["education"].isin(["Bachelors", "Prof-school", "Assoc-acdm", "Assoc-voc", "Masters", "Doctorate"]) & (data["salary"] == ">50K")]["age"].count()) == 0
# Out:
# False

# %% [markdown]
# 9. Выведите статистику возраста для каждой расы (признак race) и каждого пола. Используйте groupby и describe. Найдите таким образом максимальный возраст мужчин расы Amer-Indian-Eskimo.

# %%
for race, sub_df in data.groupby("race"):
    print(race)
    print(sub_df['age'].mean())
# Out:
# Amer-Indian-Eskimo
# 37.17363344051447
# Asian-Pac-Islander
# 37.74687199230029
# Black
# 37.7679257362356
# Other
# 33.457564575645755
# White
# 38.76988064423354

# %% [markdown]
# 8. Среди кого больше доля зарабатывающих много (>50K): среди женатых или холостых мужчин (признак marital-status)? Женатыми считаем тех, у кого marital-status начинается с Married (Married-civ-spouse, Married-spouse-absent или Married-AF-spouse), остальных считаем холостыми.

# %%
(data[(data['sex'] == 'Male') & (data['salary'] == '>50K') & (data['marital-status'].str.startswith('Married'))]['age'].count()/ \
data[(data['sex'] == 'Male') & (data['salary'] == '>50K') & (~data['marital-status'].str.startswith('Married'))]['age'].count()) > 1
# Out:
# True

# %% [markdown]
# 9. Какое максимальное число часов человек работает в неделю (признак hours-per-week)? Сколько людей работают такое количество часов и каков среди них процент зарабатывающих много?

# %%
data['hours-per-week'].max()
data[data['hours-per-week'] == data['hours-per-week'].max()]['age'].count()
# Out:
# 85

# %%
(data[(data['hours-per-week'] == data['hours-per-week'].max()) & (data['salary'] == '50K>')]['age'].count()/\
data[data['hours-per-week'] == data['hours-per-week'].max()]['age'].count()) * 100
# Out:
# 29.411764705882355

# %% [markdown]
# 10. Посчитайте среднее время работы (hours-per-week) зарабатывающих мало и много (salary) для каждой страны (native-country).

# %%
for country, sub_df in data.groupby('native-country'):
    print(country)
    print('>50K  -- ', sub_df[sub_df['salary'] == ">50K"]['hours-per-week'].mean())
    print('<=50K -- ',sub_df[sub_df['salary'] == "<=50K"]['hours-per-week'].mean())
# Out:
# ?
# >50K  --  45.54794520547945
# <=50K --  40.16475972540046
# Cambodia
# >50K  --  40.0
# <=50K --  41.416666666666664
# Canada
# >50K  --  45.64102564102564
# <=50K --  37.91463414634146
# China
# >50K  --  38.9
# <=50K --  37.38181818181818
# Columbia
# >50K  --  50.0
# <=50K --  38.68421052631579
# Cuba
# >50K  --  42.44
# <=50K --  37.98571428571429
# Dominican-Republic
# >50K  --  47.0
# <=50K --  42.338235294117645
# Ecuador
# >50K  --  48.75
# <=50K --  38.041666666666664
# El-Salvador
# >50K  --  45.0
# <=50K --  36.03092783505155
# England
# >50K  --  44.53333333333333
# <=50K --  40.483333333333334
# France
# >50K  --  50.75
# <=50K --  41.05882352941177
# Germany
# >50K  --  44.97727272727273
# <=50K --  39.13978494623656
# Greece
# >50K  --  50.625
# <=50K --  41.80952380952381
# Guatemala
# >50K  --  36.666666666666664
# <=50K --  39.36065573770492
# Haiti
# >50K  --  42.75
# <=50K --  36.325
# Holand-Netherlands
# >50K  --  nan
# <=50K --  40.0
# Honduras
# ...
